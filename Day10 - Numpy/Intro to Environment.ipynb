# %% [markdown]
# Environments
#     - as folders that carry some important packages / libraries
#
# - A Python environment is an isolated workspace containing a specific version of the Python interpreter, its standard library, and a collection of unique packages or dependencies.

# %% [markdown]
# we have already done:
#     - pip install "requests" "pillow" "numpy"
#
# Package     Purpose
# `requests` - Used to make HTTP requests and work with APIs/websites.
# `pillow`   - Used for image processing (open, edit, resize, save images).
# `numpy`    - Used for numerical calculations, arrays, and data processing.

# %% [markdown]
# 2 environment

# %%
pip install "requests" "pillow" "numpy"
