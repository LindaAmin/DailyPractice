# %% [markdown]
# Modularity
# - modular design - create diff modules
#
# Reusability
# - use an already written piece of code again & again
#
# Import
# - we have pre written libararies of code in python
# - we use the import keyboard to bring their context into a program

# %% [markdown]
# - A MODULE is a single file - like a single python script
# - A PACKAGE - a  folder that holds multiple related files together. multiple module can exist in the package
# - libraries are packages that we can install & use
#     - bundles packages & modules together to solve a bid & specific problem
#     - library can hold multiple packages too
#     - a giant Toolbox
# - we use the pip package of python to install a library
# - example:
#     - pip install request pillow numpy pandas
#
# Library examples:
#     - request - used to connect to internet
#     - numpy - used for numbers, numerical operations
#     - pandas - used for data analysis, deals with tubular data as well
#     - matplotib - used for creatting visual like bar graph, line etc
#     - there are libraries for every single thing you can imagine in python
#
# - Python , open the folder/file & let use the tools inside
#     - import tkinter
#     - import requests

# %%
### Exercise
#1. please create a script file "greet" that has a function inside
    # - hello() - should print a hello message

def greet(name = "Sisipus"):
    print(f'Hello {name}, to this world')
 
def evening (name = "Othello")
    print (f"Good Evening, Selamat Petang {name}")

def morning
greet("Linda")
# Out:
# Hello Linda, to this world

# %%
import math
import time
import sys

# %%
import test_project.greet as greeting

# we cant execute script files like this in notebooks

greeting.hello("Linda Amin")
# Out:
# Hello Linda Amin, to this world

# %%
from test_project import greet

greet.evening("Linda Amin")
# Out:
# Good Evening, salamat petang Linda Amin

# %% [markdown]
# ## Micro School Management System Project
# - Discuss:
#     - what things shiold be there?
# - Requirement:
#     - Website - for school to be visible
#     - Records:
#         - Info every person involved
#             - can have diff role
#                 - diff responsibilities
#                 - diff data that is impotrant
#     - Record updates:
#         - get records
#         - modify records
#         - delete records
#     - Data Analysis of the data we are saving in databases
#     - Adding other code for ew things that are happenings
#     - there can be much more

# %% [markdown]
# Guidance:
# 1. Creating a folder - Packages - name it properly
# 2. Problem Scoping / Statement - is where you decide what to achieve
#     - also the part the decides what not to do
#     - PS: create differents classes for diff roles in the school
#         - we research & find what the toles exactly do & then
#         - as as many function for those roles as possible
#
# 3. Setting up an Architecture:
#     - create a clean folder structure
#     -
#
# 4. creatting the files & start coding from the core modules
#     - e.g
#
# 5.

# %% [markdown]
# ##### Architecture
#
# SchoolManagementSystem
# - init.py - runs automatically
#     - init does not metter much when we are running the scripts
#     - if we decide to use this package in our notebooks, then we will see the init being used a lot
#     - every time we import the SMS e will be executing init automatically
# - main.py - entry point to the application program
# - models.py - classes
#     - Teacher_model.py
#     - Student_model.py
# - manager.py - logic to manage (view & controller) the data. View & add things
# - utils.py - API

# %%
import SchoolManagementSystem
