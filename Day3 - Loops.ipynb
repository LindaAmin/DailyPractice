# %%
for i in range (100):
    print("Linda Amin")
# Out:
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# Linda Amin
# ...

# %%
print("Linda Amin")
# Out:
# Linda Amin

# %%
print("Linda Amin" * 100)
# Out:
# Linda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda AminLinda Am
# ...

# %%
adj = ["red", "big", "tasty"]
fruits = ["apples", "banana", "cherry"]

for x in adj:
  for y in fruits:
    print(x, y)
# Out:
# red apples
# red banana
# red cherry
# big apples
# big banana
# big cherry
# tasty apples
# tasty banana
# tasty cherry
